# %%
import pandas as pd

# %%
df=pd.read_csv("titanic_train.csv")

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
Sud=df

# %%
Mean=Sud["Age"].mean()
Sud["Age"].fillna(Mean , inplace= True)
Sud
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17668\1224499618.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Sud["Age"].fillna(Mean , inplace= True)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# ...

# %%
Sud.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
Sud["Embarked"]=Sud["Embarked"].fillna(Sud["Embarked"].mode()[0])

# %%
Sud.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
Medi=df["Fare"].median()
for x in Sud.index:
    if df.loc[x , "Fare"]<=0:
        df.loc[x , "Fare"]= Medi
print("Number of negative fares:", (df['Fare'] < 0).sum())
# Out:
# Number of negative fares: 0

# %%
mean=Sud["Age"].mean()
for x in Sud.index:
    if Sud.loc[x,"Age"]>100:
        Sud.loc[x,"Age"]=mean
print("Number of ages greater than 100:", (Sud['Age'] > 100).sum())
# Out:
# Number of ages greater than 100: 0

# %%
Sud["Fare"].astype(float)
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
Sud["Cabin"] = Sud["Cabin"].str.split().str[0]

# %%
print(Sud["Cabin"].head())
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# Name: Cabin, dtype: object

# %%
def extract_first_cabin(cabin):
    if pd.isnull(cabin):
        return cabin  # Return NaN if the cabin value is missing (null)
    # Split by spaces and return the first cabin number
    return cabin.split()[0]

# Apply the function to the 'Cabin' column
Sud["firstCabin"] = Sud["Cabin"].apply(extract_first_cabin)
Sud
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
S=Sud.duplicated().sum()
S
# Out:
# 0

# %%
Sud["Name_duplicates"]=Sud["Name"]

# %%
Sud
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
Sud.drop(columns=["Name_duplicates"], inplace=True)

# %%
Sud
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
Sl=pd.read_csv("AB_NYC_2019.csv")
Sl
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
Sl.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
Sl["reviews_per_month"]=Sl["reviews_per_month"].fillna(Sl["reviews_per_month"].mean())

# %%
Sl.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
Sl["last_review"]=pd.to_datetime(Sl["last_review"])

# %%
Sl["last_review"]=Sl["last_review"].fillna(Sl["last_review"].mean())

# %%
Sl.isnull().sum()
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
s=Sl["price"].median()
for x in Sl.index:
    if Sl.loc[x,"price"]<0:
        Sl.loc[x,"price"]=s

# %%
c=Sl["minimum_nights"].mean()
for x in Sl.index:
    if Sl.loc[x,"minimum_nights"]>365:
        Sl.loc[x,"minimum_nights"]=c
# Out:
# C:\Users\Sudha\AppData\Local\Temp\ipykernel_22212\743543958.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.029962163820431' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Sl.loc[x,"minimum_nights"]=c

# %%
Sl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  float64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
Sl["price"].astype(float)
# Out:
# 0        149.0
# 1        225.0
# 2        150.0
# 3         89.0
# 4         80.0
#          ...
# 48890     70.0
# 48891     40.0
# 48892    115.0
# 48893     55.0
# 48894     90.0
# Name: price, Length: 48895, dtype: float64

# %%
Sl.duplicated().sum()
# Out:
# 0

# %%
Gl=pd.read_csv("global_power_plant_database.csv")
Gl
# Out:
# C:\Users\Sudha\AppData\Local\Temp\ipykernel_22212\560439146.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   Gl=pd.read_csv("global_power_plant_database.csv")
#       country country_long                                               name  \
# 0         AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1         AFG  Afghanistan                                       Kandahar DOG
# 2         AFG  Afghanistan                                       Kandahar JOL
# 3         AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 4         AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# ...       ...          ...                                                ...
# 34931     ZMB       Zambia                                              Ndola
# 34932     ZMB       Zambia                                              Nkana
# ...

# %%
Gl.isnull().sum()
# Out:
# country                               0
# country_long                          0
# name                                  0
# gppd_idnr                             0
# capacity_mw                           0
# latitude                              0
# longitude                             0
# primary_fuel                          0
# other_fuel1                       32992
# other_fuel2                       34660
# other_fuel3                       34844
# commissioning_year                17489
# owner                             14068
# source                               15
# url                                  18
# geolocation_source                  419
# wepp_id                           18702
# year_of_capacity_data             20049
# generation_gwh_2013               28519
# generation_gwh_2014               27710
# generation_gwh_2015               26733
# generation_gwh_2016               25792
# generation_gwh_2017               25436
# ...

# %%
# Identify erroneous values (outside the range 1900-2024)
erroneous_values = Gl[(Gl["commissioning_year"] < 1900) | (Gl["commissioning_year"] > 2024)]
print(erroneous_values["commissioning_year"])
# Out:
# 28213    1896.0
# 32337    1899.0
# Name: commissioning_year, dtype: float64

# %%
# Replace erroneous values with the median year
median_year = Gl["commissioning_year"].median()
Gl.loc[(Gl["commissioning_year"] < 1900) | (Gl["commissioning_year"] > 2024), "commissioning_year"] = median_year

# %%
# Check if there are any values still outside the range
print(Gl[(Gl["commissioning_year"] < 1900) | (Gl["commissioning_year"] > 2024)])
# Out:
# Empty DataFrame
# Columns: [country, country_long, name, gppd_idnr, capacity_mw, latitude, longitude, primary_fuel, other_fuel1, other_fuel2, other_fuel3, commissioning_year, owner, source, url, geolocation_source, wepp_id, year_of_capacity_data, generation_gwh_2013, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, generation_gwh_2018, generation_gwh_2019, generation_data_source, estimated_generation_gwh_2013, estimated_generation_gwh_2014, estimated_generation_gwh_2015, estimated_generation_gwh_2016, estimated_generation_gwh_2017, estimated_generation_note_2013, estimated_generation_note_2014, estimated_generation_note_2015, estimated_generation_note_2016, estimated_generation_note_2017]
# Index: []
#
# [0 rows x 36 columns]

# %%
if Gl['capacity_mw'].dtype != 'float64':
    Gl['capacity_mw'].astype(float)
print("\nAfter conversion:")
print(Gl.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 if Gl['capacity_mw'].dtype != 'float64':
#       2     Gl['capacity_mw'].astype(float)
#       3 print("\nAfter conversion:")
#
# NameError: name 'Gl' is not defined
