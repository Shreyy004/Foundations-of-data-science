# %%
import pandas as pd

# Specify the path to your CSV file
file_path = 'Online Retail.csv'
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# Display the first few rows of the DataFrame to verify it loaded correctly
print(df.head().to_string())
# Out:
#   ï»¿InvoiceNo StockCode                          Description  Quantity     InvoiceDate  UnitPrice  CustomerID         Country
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1       536365     71053                  WHITE METAL LANTERN         6  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
#first 10 rows
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
df.head(10).describe() #to get the summary statistics of the first 10 rows
# Out:
#         Quantity  UnitPrice   CustomerID
# count  10.000000  10.000000     10.00000
# mean    8.400000   3.276000  17369.70000
# std     8.422193   1.748194   1518.84196
# min     2.000000   1.690000  13047.00000
# 25%     6.000000   2.025000  17850.00000
# 50%     6.000000   3.070000  17850.00000
# 75%     6.000000   3.390000  17850.00000
# max    32.000000   7.650000  17850.00000

# %%
#summary statistics
df.describe()
# Out:
#            Quantity     UnitPrice    CustomerID
# count  37309.000000  37308.000000  24429.000000
# mean       8.011901      6.230193  15540.025339
# std       61.414804    148.693371   1731.742013
# min    -9360.000000      0.000000  12347.000000
# 25%        1.000000      1.280000  14210.000000
# 50%        2.000000      2.510000  15570.000000
# 75%        7.000000      4.250000  17158.000000
# max     2880.000000  13541.330000  18269.000000

# %%
#first 10 rows using iloc
df.iloc[:10]
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
df["CustomerID"].fillna(0,inplace=True)
df['CustomerID'] = df['CustomerID'].astype(object)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country
# 0  12/1/2010 8:26       2.55    17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39    17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75    17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39    17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39    17850.0  United Kingdom

# %%
cust=int(input("enter customer id: "))
cust_order=df.loc[df["CustomerID"]==cust]
print(cust_order.head())
# Out:
# enter customer id: 17850
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country
# 0  12/1/2010 8:26       2.55    17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39    17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75    17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39    17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39    17850.0  United Kingdom

# %%
filtered_df = df[df['Quantity'] > 50]

print(filtered_df.to_string().head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-67a517d70629> in <cell line: 1>()
# ----> 1 filtered_df = df[df['Quantity'] > 50]
#       2
#       3 print(filtered_df.to_string().head())
#
# NameError: name 'df' is not defined

# %%
# Sort the DataFrame by 'unit_price' in descending order
df.sort_values(by='UnitPrice', ascending=False)
# Out:
#       InvoiceNo  StockCode                  Description  Quantity  \
# 16356   C537651  AMAZONFEE                   AMAZON FEE        -1
# 15017    537632  AMAZONFEE                   AMAZON FEE         1
# 15016   C537630  AMAZONFEE                   AMAZON FEE        -1
# 16232   C537644  AMAZONFEE                   AMAZON FEE        -1
# 16357   C537652  AMAZONFEE                   AMAZON FEE        -1
# ...         ...        ...                          ...       ...
# 13960    537437      90167                          NaN        10
# 14369    537534      22620  4 TRADITIONAL SPINNING TOPS         1
# 13961    537438      22959                          NaN        13
# 17158    537687      84840                          NaN        -9
# 37308    539456     85136A      YELLOW SHARK HELICOPTER         1
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 16356  12/7/2010 15:49   13541.33         NaN  United Kingdom
# ...

# %%
df.groupby('StockCode')['Quantity'].sum().reset_index()
# Out:
#      StockCode  Quantity
# 0        10002       249
# 1        10120        16
# 2       10123C         1
# 3       10124A         4
# 4       10124G         5
# ...        ...       ...
# 2749  DCGS0076         1
# 2750       DOT        34
# 2751         M       169
# 2752      POST       182
# 2753         S        -2
#
# [2754 rows x 2 columns]

# %%
newdf = df.head(5)
cust = {
    'CustomerID': [15356,16782,17850,14733,15498],
    'CustomerName': ['John Doe', 'Jane Smith', 'Alice Johnson', 'Joe', 'Bob'],
    'CustomerSegment': ['Retail', 'Wholesale', 'Retail', 'Retail', 'Wholesale']
}
cust = pd.DataFrame(cust)
merged_df = pd.merge(newdf,cust,on ='CustomerID',how='left')
merged_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country   CustomerName  \
# 0  12/1/2010 8:26       2.55    17850.0  United Kingdom  Alice Johnson
# 1  12/1/2010 8:26       3.39    17850.0  United Kingdom  Alice Johnson
# 2  12/1/2010 8:26       2.75    17850.0  United Kingdom  Alice Johnson
# 3  12/1/2010 8:26       3.39    17850.0  United Kingdom  Alice Johnson
# 4  12/1/2010 8:26       3.39    17850.0  United Kingdom  Alice Johnson
#
#   CustomerSegment
# 0          Retail
# 1          Retail
# 2          Retail
# 3          Retail
# 4          Retail

# %%
# print(df["CustomerID"].unique())

# %%
newdf.set_index('CustomerID',inplace = True)
cust.set_index('CustomerID',inplace = True)
joined_df = newdf.join(cust)
print(joined_df.to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b3fb11806ac7> in <cell line: 1>()
# ----> 1 newdf.set_index('CustomerID',inplace = True)
#       2 cust.set_index('CustomerID',inplace = True)
#       3 joined_df = newdf.join(cust)
#       4 print(joined_df.to_string())
#
# NameError: name 'newdf' is not defined

# %%
print(pd.concat([newdf,cust],ignore_index=True))
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# 5       NaN       NaN                                  NaN       NaN
# 6       NaN       NaN                                  NaN       NaN
# 7       NaN       NaN                                  NaN       NaN
# 8       NaN       NaN                                  NaN       NaN
# 9       NaN       NaN                                  NaN       NaN
#
#       InvoiceDate  UnitPrice         Country   CustomerName CustomerSegment
# 0  12/1/2010 8:26       2.55  United Kingdom            NaN             NaN
# ...

# %%
df['total_price'] = df['Quantity'] * df['UnitPrice']
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country  total_price
# 0  12/1/2010 8:26       2.55    17850.0  United Kingdom        15.30
# 1  12/1/2010 8:26       3.39    17850.0  United Kingdom        20.34
# 2  12/1/2010 8:26       2.75    17850.0  United Kingdom        22.00
# 3  12/1/2010 8:26       3.39    17850.0  United Kingdom        20.34
# 4  12/1/2010 8:26       3.39    17850.0  United Kingdom        20.34

# %%
df.loc[df['StockCode'] == '85123A', 'Description'] = 'Updated Description'
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A                  Updated Description         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country  total_price
# 0  12/1/2010 8:26       2.55    17850.0  United Kingdom        15.30
# 1  12/1/2010 8:26       3.39    17850.0  United Kingdom        20.34
# 2  12/1/2010 8:26       2.75    17850.0  United Kingdom        22.00
# 3  12/1/2010 8:26       3.39    17850.0  United Kingdom        20.34
# 4  12/1/2010 8:26       3.39    17850.0  United Kingdom        20.34
